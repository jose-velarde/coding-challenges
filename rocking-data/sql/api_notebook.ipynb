# %%
import requests

# Get data for notebooks comparisson
products_response = []
for product_query in ["notebook acer", "notebook samsung", "notebook apple"]:
    products_response.append(
        requests.get(
            "https://api.mercadolibre.com/sites/MLA/search?"
            + "q="
            + product_query
            + "&limit=50#json"
        )
    )

items_response = []
for response in products_response:
    items_query_response = []
    for item in response.json()["results"]:
        items_query_response.append(
            requests.get("https://api.mercadolibre.com/items/" + item["id"])
        )
    items_response.append(items_query_response)

items_list_product = []
for items_response_list in items_response:
    item_results = []
    for item_response in items_response_list:
        item_results.append(item_response.json())
    items_list_product.append(item_results)

items_list_data = []
for item_results in items_list_product:
    items_data = []
    for item in item_results:
        items_data.append(
            {
                "id": item["id"],
                "title": item["title"],
                "price": item["price"],
                "available_quantity": item["available_quantity"],
                "sold_quantity": item["sold_quantity"],
                "condition": item["condition"],
            }
        )
    items_list_data.append(items_data)

acer_data = items_list_data[0]
samsung_data = items_list_data[1]
apple_data = items_list_data[2]

# %%
acer_data
# Out:
# [{'id': 'MLA926042622',
#   'title': 'Notebook Acer Aspire 3 A315-56 Steel Gray 15.6 , Intel Core I5 1035g1  8gb De Ram 256gb Ssd, Intel Uhd Graphics G1 1920x1080px Windows 10 Home',
#   'price': 97000,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA1106598246',
#   'title': 'Notebook Acer Aspire 3 A315-56-526a Shale Black 15.6 , Intel Core I5 1035g1  8gb De Ram 1000gb Hdd, Intel Uhd Graphics 60 Hz 1366x768px Windows 10 Home',
#   'price': 121999,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA1101314313',
#   'title': 'Notebook Acer Swift 3 Sf314-42 Pure Silver 14 , Amd Ryzen 7 4700u  8gb De Ram 512gb Ssd, Amd Radeon Vega 7 1920x1080px Windows 10 Home',
#   'price': 126545,
#   'available_quantity': 1,
#   'sold_quantity': 25,
#   'condition': 'new'},
#  {'id': 'MLA1108792666',
#   'title': 'Notebook Acer Aspire 5 A515-54-39wg Charcoal Black 15.6 , Intel Core I3 10110u  4gb De Ram 1000gb Hdd, Intel Uhd Graphics 60 Hz 1920x1080px Windows 10 Home',
#   'price': 72939.0,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA927707164',
#   'title': "Notebook Acer Intel Celeron N4500 4gb 128gb 15.6'' Fhd Win10",
#   'price': 59999,
#   'available_quantity': 2,
#   'sold_quantity': 75,
#   'condition': 'new'},
#  {'id': 'MLA932770558',
#   'title': 'Notebook Acer Spin 11.6 Hd Tactil 8-core 4gb 32gb Chrome Os',
#   'price': 40999,
#   'available_quantity': 1,
#   'sold_quantity': 25,
#   'condition': 'new'},
#  {'id': 'MLA1106565956',
#   'title': 'Notebook Acer Aspire 3 A315-23-r326 Charcoal Black 15.6 , Amd Amd Ryzen 3 3250u  4gb De Ram 1000gb Hdd, Amd Radeontm Vega8 Mobile Graphics 60 Hz 1366x768px Windows 10 Home',
#   'price': 87999,
#   'available_quantity': 1,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA1106720169',
#   'title': 'Notebook Acer Aspire 3 A315-56-38c3 Shale Black 15.6 , Intel Core I3 1005g1  4gb De Ram 1000gb Hdd, Intel Uhd Graphics 60 Hz 1920x1080px Windows 10 Home',
#   'price': 85999,
#   'available_quantity': 50,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA918319325',
#   'title': 'Notebook Acer Aspire 5 A515-43 Silver 15.6 , Amd Ryzen 3 3200u  4gb De Ram 128gb Ssd, Amd Radeon Vega 3 1920x1080px Windows 10 Home',
#   'price': 89999,
#   'available_quantity': 500,
#   'sold_quantity': 25,
#   'condition': 'new'},
#  {'id': 'MLA933442359',
#   'title': 'Notebook Acer Aspire 5 I5-10210u 8gb 1tb 15.6  Fhd Gris D1',
#   'price': 121499,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA921892158',
#   'title': 'Notebook Acer Gateway Ryzen 5 10ma 8gb 256 Gb Ssd Win 10',
#   'price': 84999,
#   'available_quantity': 1,
#   'sold_quantity': 20,
#   'condition': 'new'},
#  {'id': 'MLA919627476',
#   'title': 'Notebook Acer Spin 3 - 2 En 1 Touch I5 256gb Ssd 8gb',
#   'price': 109000,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA922428542',
#   'title': 'Notebook Acer Aspire 3 A315 15.6 I5 8gb 1tb',
#   'price': 121999,
#   'available_quantity': 1,
#   'sold_quantity': 25,
#   'condition': 'new'},
#  {'id': 'MLA932569804',
#   'title': 'Notebook Acer Spin 11.6 Hd Touch 8core 4gb 32gb Chrome Os',
#   'price': 53999,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA930192039',
#   'title': 'Notebook Acer Celeron N4500 128gb Emmc 4gb Ram 15.6 Silver. ',
#   'price': 58155.51,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA922430096',
#   'title': 'Notebook Acer Aspire 3 A315 15.6 I3 4gb 1tb',
#   'price': 85999,
#   'available_quantity': 50,
#   'sold_quantity': 25,
#   'condition': 'new'},
#  {'id': 'MLA932436441',
#   'title': 'Notebook Acer Aspire 5 I3 4gb 1 Tb 15.6 Ips W10',
#   'price': 89999,
#   'available_quantity': 50,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA935236308',
#   'title': 'Notebook Acer Spin 11.6 Hd Flex 8core 4gb 32gb Chrome Os',
#   'price': 40999,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA932478785',
#   'title': 'Notebook Acer Spin 11.6 Hd Octa-core 4gb 32gb Chrome Os',
#   'price': 40999,
#   'available_quantity': 1,
#   'sold_quantity': 25,
#   'condition': 'new'},
#  {'id': 'MLA914435108',
#   'title': 'Notebook Ssd Ryzen Computadora Portatil 15.6 Pulgadas Laptop',
#   'price': 120719,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA933442100',
#   'title': 'Notebook Acer Aspire 5 I5-10210u 8gb 1tb 15.6  Fhd Gris D1',
#   'price': 99999,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA931435359',
#   'title': 'Notebook Acer Aspire 5 Ryzen 3 3350u 4gb Ram 128gb Ssd 15.6 ',
#   'price': 83065.88,
#   'available_quantity': 1,
#   'sold_quantity': 4,
#   'condition': 'new'},
#  {'id': 'MLA933837566',
#   'title': 'Notebook Acer 15.6 Fhd Intel Celeron 4gb 128gb Ssd Windows ',
#   'price': 53000,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA1105452479',
#   'title': 'Notebook Acer Aspire 3 A315-34 Negra 15.6 , Intel Celeron N4000  4gb De Ram 500gb Hdd, Intel Hd Graphics 620 1366x768px Windows 10 Home',
#   'price': 67704,
#   'available_quantity': 1,
#   'sold_quantity': 2,
#   'condition': 'new'},
#  {'id': 'MLA933663881',
#   'title': 'Notebook Acer I7 11va 16gb Ssd 1tb Full Hd Iris Xe 15,6 Alum',
#   'price': 189999,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA930933348',
#   'title': 'Notebook Acer Swift 3 14  Ryzen 7 4700u 8gb 512gb Ssd Win 10',
#   'price': 149500,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA932436846',
#   'title': 'Notebook Acer Aspire 5 I5 4gb 256ssd Pcie 14 Ips W10',
#   'price': 96999,
#   'available_quantity': 100,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA932775485',
#   'title': 'Notebook Acer A515 15.6 Fhd Core I3 10ma 4gb 128gb Windows10',
#   'price': 72999,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA1104394776',
#   'title': 'Notebook Acer Ryzen 5 5500u Hexa 8gb Ssd512 15,6 Fullhd Alum',
#   'price': 119999,
#   'available_quantity': 1,
#   'sold_quantity': 4,
#   'condition': 'new'},
#  {'id': 'MLA919490234',
#   'title': 'Notebook Acer Aspire I7 12gb 11gen 1165g7 Ssd512 15.6 Win10',
#   'price': 152000,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA927706671',
#   'title': "Notebook Acer Intel Celeron N4500 4gb 128gb 15.6'' Fhd Win10",
#   'price': 74999,
#   'available_quantity': 2,
#   'sold_quantity': 10,
#   'condition': 'new'},
#  {'id': 'MLA923955331',
#   'title': 'Notebook Acer A315-22 Negra 15.6 , Amd A4-series 9120e  4gb De Ram 500gb Hdd, Amd Radeon M4 1366x768px Windows 10 Home',
#   'price': 79999,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA932170141',
#   'title': 'Notebook Acer Spin 3 14 Touch Tablet Ryzen 3 Ssd 128gb 4gb',
#   'price': 69999,
#   'available_quantity': 1,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA1107133395',
#   'title': 'Notebook Acer Nitro 5 I5-10300h 8g 256 Ssd Gtx1650 W10 15.6',
#   'price': 149999,
#   'available_quantity': 1,
#   'sold_quantity': 2,
#   'condition': 'new'},
#  {'id': 'MLA930507566',
#   'title': 'Notebook Acer Gateway Ryzen 5 10ma 16gb 256 Gb Ssd Win 10',
#   'price': 92999,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA926271623',
#   'title': 'Notebook Acer Nitro I5 10300h Gtx 1650 16gb 256gb Ssd 1tb Hd',
#   'price': 170990,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA923894669',
#   'title': 'Chromebook Acer 315 N4000 4gb 32gb Notebook 15.6 Chrome Os',
#   'price': 64269,
#   'available_quantity': 1,
#   'sold_quantity': 2,
#   'condition': 'new'},
#  {'id': 'MLA934027113',
#   'title': 'Notebook Acer Nitro 5 An515 15.6 Intel I5 512gb 16gb Rtx3050',
#   'price': 199999.99,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA912338149',
#   'title': 'Notebook Acer Nitro 5 15,6  Core I5 8gb 1tb An515-55-54as',
#   'price': 149999,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA1106851592',
#   'title': 'Notebook Acer Aspire 5 I7 10ma 15,6 Full Hd 8gb Ssd 500gb',
#   'price': 128999,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA933678009',
#   'title': 'Acer Aspire 5 I5 8gb 256gb Ssd 15,6 Full Hd Win 10 Tecl Esp.',
#   'price': 114900,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA930331323',
#   'title': 'Notebook Acer Gateway Intel I3 10ma 4gb 128gb Ssd Win 10 14',
#   'price': 73999,
#   'available_quantity': 3,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA935231429',
#   'title': 'Notebook Acer Aspire 5 I3-1005g1 4gb Ram 128gb Ssd 15.6 Silv',
#   'price': 76831.09,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA1100835561',
#   'title': 'Notebook Acer 11.6 Hd 8 Core 4gb 32gb Bt Wifi Chrome Os',
#   'price': 40799,
#   'available_quantity': 50,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA1101324160',
#   'title': "Notebook Acer Swift Amd Ryzen 7 4700u 8gb 512gb Ssd 14'' Fhd",
#   'price': 126545,
#   'available_quantity': 1,
#   'sold_quantity': 4,
#   'condition': 'new'},
#  {'id': 'MLA1104372835',
#   'title': 'Acer Predator Triton 300 I7 11va 16gb 512gb Ssd Rtx3060 14  ',
#   'price': 275000,
#   'available_quantity': 1,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA877132673',
#   'title': 'Notebook Acer Aspire 3 Celeron N4000 4gb 500gb 15.6',
#   'price': 74995,
#   'available_quantity': 1,
#   'sold_quantity': 4,
#   'condition': 'new'},
#  {'id': 'MLA1106282940',
#   'title': "Notebook Acer Aspire 5 Intel I5-1135g7 8gb 256gb 14'' Fhd ",
#   'price': 119999,
#   'available_quantity': 1,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA921806382',
#   'title': 'Notebook Acer Aspire 3 15.6 Core I5 8gb 256gb Windows 10',
#   'price': 114999,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA933095922',
#   'title': 'Notebook Acer I7 16gb 512ssd 17.3 Fhd Garantia Original',
#   'price': 178000,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'}]

# %%
samsung_data
# Out:
# [{'id': 'MLA933488331',
#   'title': 'Notebook 2en1 Samsung Galaxy Flex I7 11va 16gb Ssd512 13,3 ',
#   'price': 216199.06,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA1105125967',
#   'title': 'Notebook Samsung Galaxy Book Pro 15.6  I7 11va 16gb Ssd 512',
#   'price': 265999.05,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1105329578',
#   'title': 'Galaxy Book Pro Core I7 11va 15.6 Amoled 16gb 512ssd Win 10',
#   'price': 325999,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1106228211',
#   'title': 'Galaxy Book Pro 15,6 - I7 Amoled 16gb 1tb Win 10 Mystic Blue',
#   'price': 402500,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1109740749',
#   'title': 'Notebook 2en1 Samsung Galaxy Flex I7 11va 16gb Ssd512 13,3 ',
#   'price': 198000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA847468901',
#   'title': 'Samsung Odyssey 15,6 I7-9750h 16gb 512gb Ssd Rtx 2060',
#   'price': 293910.57,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1109850740',
#   'title': 'Notebook 2en1 Samsung Galaxy Flex I7 11va 16gb Ssd512 13,3 ',
#   'price': 198000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876510464',
#   'title': 'Renovada) Samsung Chrome Os 15.6 Full Hd Intel Celeron Proce',
#   'price': 97499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876510541',
#   'title': 'Renovada) Samsung Galaxy Book 2 Att Sm-w737a Silver Qualcomm',
#   'price': 143105,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876512024',
#   'title': 'Renovada) Samsung Notebook 7 13.3 8gb Ram 256gb Ssd',
#   'price': 133499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876511964',
#   'title': 'Renovada) Samsung Notebook 7 Spin 2-in-1 13.3 Touch-screen L',
#   'price': 202162,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876511169',
#   'title': 'Renovada) Samsung 15.6-inch Hd Touchscreen Laptop 7th Intel',
#   'price': 133499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA922103079',
#   'title': 'Notebook Samsung I5',
#   'price': 54000,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA869373495',
#   'title': 'Notebook Samsung 15.6 Intel Pentium 4gbram Hdd300gb Ssd240gb',
#   'price': 63300,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA869806936',
#   'title': 'Samsung I5  Ssd 500 Gb. Windows 10',
#   'price': 62000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1109613490',
#   'title': 'Notebook Samsung Np300e5a',
#   'price': 36000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876510168',
#   'title': 'Renovada) Samsung Notebook 7 15.6 16gb Ram 512gb Ssd Mx250®',
#   'price': 166599,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876510308',
#   'title': 'Renovada) Samsung Notebook 7 13.3 16gb Ram 512gb Ssd',
#   'price': 150499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA866767444',
#   'title': 'Cargadaro Samsung Notebook',
#   'price': 2500,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876497799',
#   'title': 'Renovada) Samsung Notebook 7 15.6 16gb Ram 512gb Ssd Mx250',
#   'price': 166499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876497873',
#   'title': 'Renovada) Samsung Notebook 9 Pen 15-intel Core I7-16gb Memor',
#   'price': 249499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876506473',
#   'title': 'Renovada) Samsung Notebook 9 Pen 15-intel Core I7-16gb Memo®',
#   'price': 249599,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA876509802',
#   'title': 'Renovada) Samsung Galaxy Book S 13.3 Fhd Touchscreen | Intel',
#   'price': 145499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932830713',
#   'title': '® Samsung Notebook 9 Pro 15 Pen 2tb Ssd 16gb Ram Extreme Fa',
#   'price': 611475,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932827646',
#   'title': '® Samsung Notebook 9 Pro 2-in-1 Business 15 Fhd Touchscreen',
#   'price': 363808.66,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932828987',
#   'title': '® Samsung Notebook 7 13.3 8gb Ram 256gb Ssd',
#   'price': 185499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932832482',
#   'title': '® Samsung 2018 Galaxy Book 12 Fhd+ 2-in-1 Touchscreen Tablet',
#   'price': 391948.66,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932828284',
#   'title': '® Samsung Galaxy Chromebook 13.3 4k Touch-pantalla Business',
#   'price': 278048.66,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932828397',
#   'title': '® Samsung Notebook 9 Pro 15 Fhd 2-in-1 Touch Pantalla Laptop',
#   'price': 271499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932829024',
#   'title': '® Samsung Notebook 7 Spin 2-in-1 13.3 Fhd Touch-pantalla Lap',
#   'price': 185499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932829422',
#   'title': '® Samsung Notebook 9 Pro 2-in-1 2020 Premium Laptop 13.3 Ful',
#   'price': 302499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932829524',
#   'title': '® Samsung Notebook 7 Spin 2-in-1 13.3 Touch-pantalla Laptop',
#   'price': 260628.66,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932829659',
#   'title': '® Samsung Notebook 9 Pro 15 Fhd Touchscreen 2-in-1 Lapt 1226',
#   'price': 349068.66,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932825301',
#   'title': '® Samsung Galaxy Tabpro S 12 Full Hd+2160x1440 High Performa',
#   'price': 195499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932831645',
#   'title': '® Samsung Notebook 9 Pro 15 Pen 512gb Ssd 16gb Ram Extreme',
#   'price': 507188.66,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1101318524',
#   'title': 'Vendo Notebook Samsung.',
#   'price': 80000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1105391720',
#   'title': 'Notebook Samsung Reacondicionada ',
#   'price': 40000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1107684406',
#   'title': 'Nootbook Samsung',
#   'price': 55000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1108114504',
#   'title': 'Notebook Samsung 15 Np270e5e, 4 Gb Ram, 500 Gb Disco Duro ',
#   'price': 37000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA928526972',
#   'title': 'Notebook Samsung Np300e4c I5 3210m 4gb 240gb Ssd - Zoom-meet',
#   'price': 78000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA932898238',
#   'title': 'Notebook Samsung Rv509 Para Repuestos',
#   'price': 35000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA900397591',
#   'title': 'Notebook Samsung Np300e5a - Intel 1.5ghz/4gb Ram/500gb Hdd',
#   'price': 45000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA1103559821',
#   'title': 'Notebook Samsung Np300e5 Buen Estado Y Funcionalidad, Leer',
#   'price': 32448,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA776654586',
#   'title': 'Samsung Notebook Np300e5a. Para Reparar. Nuñez',
#   'price': 30000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA1109212822',
#   'title': 'Notebook Samsung Np 27 Windows 7 ,celeron 4 Gb No Se Envía!!',
#   'price': 44000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA1106783930',
#   'title': 'Samsung Np300 E5a-core I5-disco Solido-ram 6gb',
#   'price': 64999,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA885964077',
#   'title': 'Notebook Samsung Rv511 - 4gb !!!',
#   'price': 28000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA921810166',
#   'title': 'Notebook Samsung Modelo Rv511 4gb De Ram  Intel Pentium  ',
#   'price': 30000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA859039514',
#   'title': 'Samsung Potente! Core I3 2,50 Ghz Turbo 8 Gb Ram Intacta!',
#   'price': 59500,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'},
#  {'id': 'MLA913930406',
#   'title': 'Notebook Samsung R430 Muy Buen Estado',
#   'price': 54000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'used'}]

# %%
apple_data
# Out:
# [{'id': 'MLA913900147',
#   'title': 'Macbook Air A1466 Plata 13.3 , Intel Core I5 5350u  8gb De Ram 128gb Ssd, Intel Hd Graphics 6000 1440x900px Macos',
#   'price': 154999,
#   'available_quantity': 250,
#   'sold_quantity': 250,
#   'condition': 'new'},
#  {'id': 'MLA911215223',
#   'title': 'Apple Macbook Air 13 Core I5 1.8ghz 8gb 128gb Ssd',
#   'price': 154999,
#   'available_quantity': 250,
#   'sold_quantity': 200,
#   'condition': 'new'},
#  {'id': 'MLA903179553',
#   'title': 'Apple Macbook Air 13.3 2020 Intel Core I5 512gb',
#   'price': 259999,
#   'available_quantity': 1,
#   'sold_quantity': 25,
#   'condition': 'new'},
#  {'id': 'MLA1108656051',
#   'title': 'Apple Macbook Pro (13 Pulgadas, Touch Bar, Cuatro Puertos Thunderbolt 3, 1 Tb De Ssd) - Gris Espacial',
#   'price': 375439.05,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA913817142',
#   'title': 'Macbook Air A2179 Plata 13.3 , Intel Core I3 1000ng4  8gb De Ram 256gb Ssd, Intel Iris Plus Graphics 2560x1600px Macos',
#   'price': 239999,
#   'available_quantity': 5000,
#   'sold_quantity': 2,
#   'condition': 'new'},
#  {'id': 'MLA829595674',
#   'title': 'New Macbook Pro Retina 2020 Touchbar I5 8gb Garantía Factura',
#   'price': 279999,
#   'available_quantity': 500,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA1104043541',
#   'title': 'Apple Macbook Pro (13 Pulgadas, Touch Bar, Cuatro Puertos Thunderbolt 3, 512 Gb De Ssd) - Gris Espacial',
#   'price': 356199,
#   'available_quantity': 1,
#   'sold_quantity': 5,
#   'condition': 'new'},
#  {'id': 'MLA1104012093',
#   'title': 'Apple Macbook Pro (13 Pulgadas, Touch Bar, Cuatro Puertos Thunderbolt 3, 512 Gb De Ssd) - Plata',
#   'price': 338389.05,
#   'available_quantity': 1,
#   'sold_quantity': 2,
#   'condition': 'new'},
#  {'id': 'MLA925837318',
#   'title': 'Apple Macbook Pro (16 Pulgadas, Intel Core I9, 1 Tb De Ssd, 16 Gb De Ram, Amd Radeon Pro 5500m) - Gris Espacial',
#   'price': 590000,
#   'available_quantity': 1,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA1108675555',
#   'title': 'Apple Macbook Pro (13 Pulgadas, Touch Bar, Cuatro Puertos Thunderbolt 3, 1 Tb De Ssd) - Plata',
#   'price': 395199,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA653282516',
#   'title': 'Macbook Air Modelo A1466 13.3 I5 8gb Ssd 512/256/128 Garanti',
#   'price': 189999,
#   'available_quantity': 500,
#   'sold_quantity': 4,
#   'condition': 'new'},
#  {'id': 'MLA913817129',
#   'title': 'Macbook Air A2179 Gris Espacial 13.3 , Intel Core I3 1000ng4  8gb De Ram 256gb Ssd, Intel Iris Plus Graphics 2560x1600px Macos',
#   'price': 239999,
#   'available_quantity': 500,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA930955712',
#   'title': 'Macbook Servicio Técnico Reparaciones Presupuestos Local ',
#   'price': 100,
#   'available_quantity': 1,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA873752733',
#   'title': 'Macbook Pro 16 Touchbar I9 Ssd 1tb 16gb Video 4gb Garantia',
#   'price': 599999,
#   'available_quantity': 50000,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA831825009',
#   'title': 'Macbook Air 2020 Retina Sensor Id Ssd256gb 18 Cuotas Sin Int',
#   'price': 239999,
#   'available_quantity': 10500,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA847744939',
#   'title': 'Macbook Pro 16 I9 8cores Ssd1tb 16gb Video 4gb Grtia. Factu',
#   'price': 599999,
#   'available_quantity': 500,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA935692152',
#   'title': 'Macbook Air A2179 13.3 Core I3 8gb 256gb Ssd Caja Abierta ',
#   'price': 137999,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA865546672',
#   'title': "Apple Macbook Pro 16'' I7 16gb 512ssd Touch Bar Español",
#   'price': 519990,
#   'available_quantity': 1,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA876980503',
#   'title': 'Macbook Pro 16 Corei9/16gb/1tb Ssd Inglés Spacgray ',
#   'price': 725920.25,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA883059954',
#   'title': 'Apple Macbook Pro 13,31 Mwp52le/a I5 Gen10 16gb Tb Ssd',
#   'price': 390999,
#   'available_quantity': 1,
#   'sold_quantity': 2,
#   'condition': 'new'},
#  {'id': 'MLA874750542',
#   'title': 'Macbook Air 13 2020 Retina Ssd 512gb I5 10ma Grantia Oficial',
#   'price': 279999,
#   'available_quantity': 50000,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA694875976',
#   'title': 'Apple Macbook Air I5 8gb 128 Ssd 13.3 Hd Factura A O B ',
#   'price': 144999,
#   'available_quantity': 1,
#   'sold_quantity': 25,
#   'condition': 'new'},
#  {'id': 'MLA919147000',
#   'title': 'Apple Macbook Pro A1706 (13-inch 2017) Core I5 8gb 256gb Ssd',
#   'price': 195000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA930406762',
#   'title': 'Macbook Pro Retina 15  Mid 2014 Refurbished I7 500gb Nvidia',
#   'price': 180000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA905831332',
#   'title': 'Macbook (retina, 12-inch, Early 2015) Model A1534 Tienda Hyt',
#   'price': 180000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA870218888',
#   'title': 'Macbook Pro 16 Touch I9 8 Cores Ssd1tb Video 4gb Grtia.fact.',
#   'price': 699999,
#   'available_quantity': 5000,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA896191886',
#   'title': 'Macbook Air 2020 256gb Adaptador Hub+auriculares+carcasa Col',
#   'price': 209999,
#   'available_quantity': 50,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA935004787',
#   'title': 'Apple Macbook Pro 16  16gb 512gb I7 Radeon Pro 5300 Plateado',
#   'price': 499999,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA916010902',
#   'title': 'Macbook Air 13  Core I5 128gb 8gb Mqd32le/a',
#   'price': 164999,
#   'available_quantity': 50,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA927055161',
#   'title': '[repuesto] Macbook Mid 2010 A1342 White Unibody 13in I5',
#   'price': 27000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA881940393',
#   'title': 'Macbook Air 2020, I5, 512gb Golden Rose!!!',
#   'price': 280000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA933621160',
#   'title': 'Macbook Pro 13 2009 I5 8gbbatería Y Disco Solido Nuevo',
#   'price': 75000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1100028489',
#   'title': 'Macbook Pro 15 Touch Bar/id 2,9 Ghz 512gb I7 Radeon Pro 560',
#   'price': 310000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA932308606',
#   'title': 'Macbook Pro 2015 13  Intel Core I5 8gb De Ram 256gb Ssd',
#   'price': 90000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA913742713',
#   'title': 'Macbook Pro A1708 (late 2016) Gris Espacial 13.3 , Intel Core I5 6360u  8gb De Ram 256gb Ssd, Intel Iris Graphics 540 60 Hz 2560x1600px Macos',
#   'price': 189999,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA879028555',
#   'title': 'Apple Macbook Mf865ksa Core M 512gb Ssd 8gb Ram 12 PuLG Silv',
#   'price': 199996.01,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA934585184',
#   'title': 'Macbook Pro Retina 13 2013 I7 8gb 512gb Big Sur',
#   'price': 100000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1109406502',
#   'title': 'Macbook Pro (retina, 15-inch, Mid 2015) I7 - 2,5ghz - 500gb',
#   'price': 230000,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA1109175880',
#   'title': 'Macbook Pro 2015 13.3 Core I5 8gb 128gb Ssd Oultet',
#   'price': 137499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA918470294',
#   'title': "Macbook Pro 2018 15.4' Retina Core I7 16gb 512gb Ssd Outlet",
#   'price': 454499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA918329256',
#   'title': "Macbook Pro 2016 15.4' Retina Core I7 16gb Ram 512gb Ssd",
#   'price': 272499,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA912596053',
#   'title': "Macbook Air 2015 11.6' Core I5 4gb Ram 128gb Ssd Outlet",
#   'price': 100499,
#   'available_quantity': 1,
#   'sold_quantity': 3,
#   'condition': 'new'},
#  {'id': 'MLA1109156804',
#   'title': "Apple Macbook Pro 2015 13' I5 8 Gb Ram 256 Ssd Outlet",
#   'price': 141499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA918473229',
#   'title': "Macbook Air 2015 13.3' Core I5 8gb Ram 256gb Ssd Outlet",
#   'price': 116499,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA932888474',
#   'title': "Apple Macbook Pro 13,3' 2017 Core I5 8gb 256gb Ssd Outlet",
#   'price': 171999,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA912276293',
#   'title': 'Macbook Pro 2015 15,4 Core I7 16gb Ram 256 Gb Ssd Outlet',
#   'price': 224999,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA918241830',
#   'title': "Macbook Pro 2014 15' Retina Core I7 16gb Ram 1tb Ssd Outlet",
#   'price': 254999,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA920153662',
#   'title': "Macbook Pro 2019 15.4' Retina Core I9 16gb Ram 512gb Ssd",
#   'price': 478999,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'},
#  {'id': 'MLA908222154',
#   'title': 'Macbook Air 2017 13.3 Core I5 8gb 256gb Ssd Outlet',
#   'price': 146499,
#   'available_quantity': 1,
#   'sold_quantity': 1,
#   'condition': 'new'},
#  {'id': 'MLA904990743',
#   'title': 'Macbook Pro 2017 Gris 13.3  Core I5 8gb 256gb Outlet',
#   'price': 313499,
#   'available_quantity': 1,
#   'sold_quantity': 0,
#   'condition': 'new'}]
